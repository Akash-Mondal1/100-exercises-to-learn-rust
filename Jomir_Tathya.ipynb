# %% [markdown]
# <a href="https://colab.research.google.com/github/Akash-Mondal1/100-exercises-to-learn-rust/blob/main/Jomir_Tathya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Read the data and set the index from 1

# %%
import pandas as pd
Gour = pd.read_csv('/content/Gour.csv')
Gour.index = range(1, len(Gour) + 1)

# %%
import pandas as pd
Nitai = pd.read_csv('/content/Nitai.csv')
Nitai.index = range(1, len(Nitai) + 1)

# %%
import pandas as pd
joydev = pd.read_csv('/content/joydev.csv')
joydev.index = range(1, len(joydev) + 1)

# %% [markdown]
# # Analyze The Data Now

# %%
import pandas as pd
Gour = pd.read_csv('/content/Gour.csv')
Gour.index = range(1, len(Gour) + 1)



import pandas as pd
Nitai = pd.read_csv('/content/Nitai.csv')
Nitai.index = range(1, len(Nitai) + 1)



import pandas as pd
joydev = pd.read_csv('/content/joydev.csv')
joydev.index = range(1, len(joydev) + 1)

# %% [markdown]
# # Common Dag No

# %%
# Step 1: Identify common 'দাগ নং'
common_all = set(Gour['দাগ নং']) & set(Nitai['দাগ নং']) & set(joydev['দাগ নং'])              # Common in all three
common_gour_nitai = (set(Gour['দাগ নং']) & set(Nitai['দাগ নং'])) - common_all               # Common in Gour & Nitai only
common_nitai_joydev = (set(Nitai['দাগ নং']) & set(joydev['দাগ নং'])) - common_all           # Common in Nitai & Joydev only

# Step 2: Filter datasets for common 'দাগ নং'
# For common in all three datasets
df_common_all = Gour[Gour['দাগ নং'].isin(common_all)][['দাগ নং', 'শ্রেণী', 'অংশ', 'অংশ পরিমাণ(একর)']]

# For common in Gour & Nitai only
df_common_gour_nitai = Gour[Gour['দাগ নং'].isin(common_gour_nitai)][['দাগ নং', 'শ্রেণী', 'অংশ', 'অংশ পরিমাণ(একর)']]

# For common in Nitai & Joydev only
df_common_nitai_joydev = Nitai[Nitai['দাগ নং'].isin(common_nitai_joydev)][['দাগ নং', 'শ্রেণী', 'অংশ', 'অংশ পরিমাণ(একর)']]

# Step 3: Display the DataFrames
print("Common in Gour, Nitai, and Joydev:")
display(df_common_all)

print("\nCommon in Gour and Nitai:")
display(df_common_gour_nitai)

print("\nCommon in Nitai and Joydev:")
display(df_common_nitai_joydev)
# Out:
# Common in Gour, Nitai, and Joydev:
#        দাগ নং  শ্রেণী     অংশ  অংশ পরিমাণ(একর)
# 2         705    শুনা  0.3333             0.03
# 3        1448  বাস্তু  0.1111             0.03
# 4        1454    ডোবা  0.3333             0.02
# 5        1455  বাস্তু  0.3333             0.04
# 8        1554    ডোবা  0.0278             0.01
# 9        1555    ডোবা  0.0280             0.01
# 11       1575    ভিটি  0.3333             0.19
# 12       1922   পুকুর  0.0278             0.01
# 13       2013    ডোবা  0.0278             0.00
# 15       2158    শালি  0.2500             0.06
# 16       2208    ডোবা  0.0278             0.02
# 17       2220    শুনা  0.0278             0.00
# 18       2222   পুকুর  0.0278             0.03
# 19       2235  বাস্তু  0.0140             0.01
# 20       2238    ভিটি  0.0833             0.01
# 25       3671    শালি  0.1188             0.18
# 28       3681    শালি  0.3333             0.11
# 31  1474/3859  বাস্তু  0.3333             0.04
# Common in Gour and Nitai:
# ...

# %% [markdown]
# # Unique Dag only for nitai

# %%
# Step 1: Identify unique 'দাগ নং' for Nitai
unique_nitai_dag = set(Nitai['দাগ নং']) - (set(Gour['দাগ নং']) | set(joydev['দাগ নং']))

# Step 2: Filter Nitai DataFrame for unique 'দাগ নং'
df_unique_nitai = Nitai[Nitai['দাগ নং'].isin(unique_nitai_dag)][['দাগ নং', 'শ্রেণী', 'অংশ', 'অংশ পরিমাণ(একর)']]

# Step 3: Display the unique data
print("Unique 'দাগ নং' for Nitai (Not in Gour or Joydev):")
display(df_unique_nitai)
# Out:
# Unique 'দাগ নং' for Nitai (Not in Gour or Joydev):
#       দাগ নং শ্রেণী     অংশ  অংশ পরিমাণ(একর)
# 8       1568   ভিটি  0.1667             0.07
# 19      3366   শালি  1.0000             0.40
# 25  653/3856   শুনা  1.0000             0.18
